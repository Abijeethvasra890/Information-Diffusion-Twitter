# %%
# !pip install tweepy
import tweepy
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tweepy in c:\users\abijeeth\appdata\roaming\python\python39\site-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\abijeeth\appdata\roaming\python\python39\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (1.16.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abijeeth\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
consumer_key = 'lrZdrASbXKlNwf7L9HnYPQAGo'
consumer_secret = '1ZNOVCLtfl8DDYgoc6uCjHoFfvjSxUKQJPoW3Jly0txJ29Ghau'
access_token = '1409487072801431558-H53tnLcScAPMYIYKtHhk1pAW02Sj93'
access_token_secret = 'vSBOvViQC97BbKSxQ75QiUsjORBQ8q77Oi6jWaIGnXuTj'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %%
me = api.get_user(screen_name = "samdro1981")
me.id
# Out:
# 838136759254978562

# %%
user_list = ["838136759254978562"]
follower_list = []
for user in user_list:
    followers = []
    try:
        for page in tweepy.Cursor(api.followers_ids, user_id=user).pages():
            followers.extend(page)
            print(len(followers))
    except tweepy.TweepError:
        print("error")
        continue
    follower_list.append(followers)
# Out:
# 39

# %%
df = pd.DataFrame(columns=['source','target']) #Empty DataFrame
df['target'] = follower_list[0] #Set the list of followers as the target column
df['source'] = me.id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 df = pd.DataFrame(columns=['source','target']) #Empty DataFrame
# ----> 2 df['target'] = follower_list[0] #Set the list of followers as the target column
#       3 df['source'] = me.id
#
# NameError: name 'follower_list' is not defined

# %%
import networkx as nx
G = nx.from_pandas_edgelist(df, 'source', 'target') #Turn df into graph
pos = nx.spring_layout(G) #specify layout for visual
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import networkx as nx
# ----> 2 G = nx.from_pandas_edgelist(df, 'source', 'target') #Turn df into graph
#       3 pos = nx.spring_layout(G)
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(10, 10))
plt.style.use('ggplot')
nodes = nx.draw_networkx_nodes(G, pos,alpha=0.8)
nodes.set_edgecolor('k')
nx.draw_networkx_labels(G, pos, font_size=8)
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.2)
plt.savefig("nodenet.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 f, ax = plt.subplots(figsize=(10, 10))
#       3 plt.style.use('ggplot')
# ----> 4 nodes = nx.draw_networkx_nodes(G, pos,alpha=0.8)
#       5 nodes.set_edgecolor('k')
#       6 nx.draw_networkx_labels(G, pos, font_size=8)
#
# NameError: name 'nx' is not defined

# %%
user_list = list(df['target']) #Use the list of followers we extracted in the code above 
for userID in user_list:
    print(userID)
    followers = []
    follower_list = []

    # fetching the user
    user = api.get_user(userID)

    # fetching the followers_count
    followers_count = user.followers_count

    try:
        for page in tweepy.Cursor(api.followers_ids, user_id=userID).pages():
            followers.extend(page)
            print(len(followers))
            if followers_count >= 5: #Only take first 5 followers
                break
    except tweepy.TweepError:
        print("error")
        continue
    follower_list.append(followers)
    temp = pd.DataFrame(columns=['source', 'target'])
    temp['target'] = follower_list[0]
    temp['source'] = userID
    df = df.append(temp)
    df.to_csv("data.csv")
# Out:
# 1070332391217078273
# 2763
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 69098454
# 327
# 1455485081594777612
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 1264
# 1131252543412199425
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 414
# 1656073075
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 202
# 284443848
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 159
# 18896884
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 751
# 1501792469507362819
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 223
# 526439855
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 2386
# 411713569
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# error
# 1951228699
# 2162
# 1605046178
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 8
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 1160502001249280000
# 5000
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 1373050159974744064
# 33
# 847392516076851208
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# Rate limit reached. Sleeping for: 844
# 1077
# 711159636989251585
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 5000
# 1369567193516683265
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 224
# 50942398
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 695
# 956236592
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 1930
# 1275076315297705989
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 28
# 3294010713
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 191
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 409545959
# 736
# 352612489
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 4047
# 761584018823479298
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 987
# 2348853575
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 518
# 127261664
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 38
# 984067923718361089
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 643
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 258719968
# 268
# 479333563
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 978
# 176933556
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# Rate limit reached. Sleeping for: 857
# 386
# 915246066869719041
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 1494
# 826788345296670725
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 38
# 776304856046964736
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 166
# 751431918084820996
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 194
# 3375753083
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 240
# 414603074
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 104
# 82709444
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 113
# 481204190
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# 80
# 173901228
# C:\Users\Abijeeth\AppData\Local\Temp\ipykernel_3392\1675833789.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp)
# error

# %%
import pandas as pd
df = pd.read_csv("data.csv") #Read into a df
G = nx.from_pandas_edgelist(df, 'source', 'target')

# %%
G.number_of_nodes() #Find the total number of nodes in this graph
# Out:
# 34713

# %%
G_sorted = pd.DataFrame(sorted(G.degree, key=lambda x: x[1], reverse=True))
G_sorted.columns = ['nconst','degree']
G_sorted.head()
# Out:
#                 nconst  degree
# 0  1160502001249280000    5000
# 1   711159636989251585    5000
# 2            352612489    4047
# 3  1070332391217078273    2764
# 4            526439855    2386

# %%
u = api.get_user(838136759254978562)
u.screen_name
# Out:
# 'samdro1981'

# %%
G_tmp = nx.k_core(G, 2) #Exclude nodes with degree less than 2

# %%
G_tmp.number_of_nodes()
# Out:
# 1086

# %%
from community import community_louvain
partition = community_louvain.best_partition(G_tmp)
#Turn partition into dataframe
partition1 = pd.DataFrame([par
                           tition]).T
partition1 = partition1.reset_index()
partition1.columns = ['names','group']

# %%
G_sorted = pd.DataFrame(sorted(G_tmp.degree, key=lambda x: x[1], reverse=True))
G_sorted.columns = ['names','degree']
G_sorted.head()
dc = G_sorted

# %%
G_sorted.head()
# Out:
#                  names  degree
# 0            352612489     324
# 1            526439855     267
# 2           1951228699     260
# 3  1455485081594777612     241
# 4   761584018823479298     210

# %%
combined = pd.merge(dc,partition1, how='left', left_on="names",right_on="names")
combined.head()
# Out:
#                  names  degree  group
# 0            352612489     324      5
# 1            526439855     267      7
# 2           1951228699     260      5
# 3  1455485081594777612     241      7
# 4   761584018823479298     210      5

# %%
combined = combined.rename(columns={"names": "Id"}) #I've found Gephi really likes when your node column is called 'Id'
edges = nx.to_pandas_edgelist(G_tmp)
nodes = combined['Id']
edges.to_csv("edges.csv")
combined.to_csv("nodes.csv")

# %%
import networkx as nx

pos = nx.spring_layout(G_tmp) #specify layout for visual

# %%
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(10, 10))
plt.style.use('ggplot')
nodes = nx.draw_networkx_nodes(G_tmp, pos,node_color="purple",alpha=0.8)
nodes.set_edgecolor('white')
#nx.draw_networkx_labels(G_tmp, pos, font_size=2)
nx.draw_networkx_edges(G_tmp, pos, width=1.0, alpha=0.2)
plt.savefig('twitterFollowers.png')
